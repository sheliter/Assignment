# %% [markdown]
# <a href="https://colab.research.google.com/github/sheliter/Assignment/blob/main/Homework_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 6: N-Gram Language Models with the Brown Corpus
#
# In this assignment you’ll practice **probabilistic language modeling (PLM)** by building N-gram models that generate text. Along the way, you’ll develop the core components of a language model: estimating conditional probabilities, calculating sentence likelihoods, and generating text using principled probabilistic strategies. The goal is to understand *how simple statistical models can produce coherent language*, and how careful choices in scoring and decoding affect the quality of generated text.
#
#
# ### Learning Objectives
#
# * Build and compare **bigram and trigram** language models.
# * Calculate **word and sentence probabilities** in log space and use them to compute **perplexity**.
# * Implement **probability-based generation** methods, including temperature-scaled sampling.
# * Explore **beam search** as a structured alternative to greedy generation.
#
#
# ### **The four problems (high level)**
#
# 1. **Problem 1 — N-gram probabilities (bigrams & trigrams):**
#    Build bigram and trigram count models from the corpus and convert next-word probabilities into **log space** to avoid numerical underflow.
#
# 2. **Problem 2 — Controlled sentence generation:**
#    Generate sentences using trigram contexts when available, **backing off to bigrams** as needed, and explore how **temperature** controls randomness in the generated text.
#
# 3. **Problem 3 — Sentence probability & perplexity:**
#    Define sentence probability in log space, normalize for sentence length using **average log probability (ALP)**, and compute **perplexity** as a measure of model quality.
#
# 4. **Problem 4 — Beam search:**
#    Implement **beam search**, ranking partial candidates by ALP during generation, then compare completed sentences using **perplexity** and contrast the results with greedy decoding.
#
#
# By the end, you’ll have a working N-Gram generator capable of producing reasonable sentences, and a solid understanding of how early probabilistic approaches to NLP laid the foundation for modern deep learning methods.

# %% [markdown]
# ### Recommended PROTOTYPING Workflow (Must Read!)
#
# One of the most important skills in machine learning is following a **disciplined prototyping workflow** when developing complex code. The basic idea, is simple:
#
# 1. **Start small:** Write and test your code using a tiny subset of your dataset.
# 2. **Inspect your results:** Print out and examine intermediate outputs to verify that each step behaves as expected.
# 3. **Iterate and tune:** Adjust hyperparameters and continue testing, gradually increasing the subset size as needed.
# 4. **Scale up:** Once you are confident your code is bug-free and your hyperparameters are roughly correct, run it on the **full dataset** to obtain your final results.
#
# If you don’t have sufficient computing resources for a full run, use **as large a subset as practical** — provided you’ve begun early enough to allow for multiple iterations.
#
#
# To help you follow this workflow in this homework, I’ve included a variable `num_sentences` that controls how many sentences are used from the shuffled Brown Corpus.
#
# I recommend the following progression:
#
# * **Step 1:** Begin with `num_sentences = 10` to debug and print out intermediate data structures (such as dictionaries) to confirm that your code works as expected.
# * **Step 2:** Increase to `num_sentences = 100` to verify correctness and complete most of the homework efficiently.
# * **Step 3:** Finally, if possible, run with the full dataset (`num_sentences = 57_340`), or as large a subset as your resources allow, to answer the graded questions.
#
#
# There are 9 problems in this homework, each worth 9 points each, and you get 4 points free if you otherwise complete the homework.

# %% [markdown]
# #### Useful Imports (add more as needed)

# %%
import math
import re
import string
import random
import spacy
import numpy as np
import pandas as pd
from tqdm import tqdm
from matplotlib import pyplot as plt
from collections import Counter

random.seed(42)

# %% [markdown]
# #### Utility Function to Pretty-Print Sentences

# %%
'''
Reconstruct a human-readable sentence from tokens.
- Capitalize the first token (after removing <s>).
- Attach any token in string.punctuation with no preceding space.
- Attach tokens starting with an apostrophe (e.g., "'s", "'ll") with no space.
- Capitalize standalone 'i' and 'god' wherever they appear.
- If the last token is '.', '?', or '!', attach it without a space.
- Ignore boundary markers <s> and </s> if present.
Returns the sentence string and also prints it depending on flag parameter.
'''

def print_sentence(tokens, do_print=True):

    if not tokens:
        print("")
        return ""

    # Drop boundary markers if present
    start = 1 if tokens and tokens[0] == "<s>" else 0
    end = -1 if tokens and tokens[-1] == "</s>" else len(tokens)
    core = tokens[start:end]

    if not core:
        print("")
        return ""

    # Capitalize first token
    out = core[0].capitalize()

    # Process remaining tokens with spacing rules
    for i, t in enumerate(core[1:], start=1):
        is_last = (i == len(core) - 1)

        # Last-token punctuation rule
        if is_last and t in {".", "?", "!"}:
            out += t
            continue

        # General punctuation attaches with no space (e.g., ',', ':', ';', ')', etc.)
        if t in string.punctuation:
            out += t
            continue

        # Apostrophe-start tokens like "'s", "'d", "'ll"
        if t.startswith("'"):
            out += t
            continue

        # Capitalize special standalone words
        if t.lower() in {"i", "god"}:
            out += " " + t.capitalize()
            continue

        # Default: add a space before normal words
        out += " " + t

    if do_print:
        print(out)
    return out

# %% [markdown]
# ### Read in the list of all sentences in the Brown Corpus and process using SPaCy.

# %%
# Must do this the first time to get the Natural Language ToolKit

# !pip install nltk

# %%
import nltk
from nltk.corpus import brown
import spacy

nltk.download('brown')

# Get all Brown corpus sentences as raw text
# Brown is organized into categories, we flatten it into one list of sentences and shuffle
# so we can create a shorter list for testing

brown_texts = [" ".join(sent) for sent in brown.sents()]

random.shuffle(brown_texts)

# Brown has 57_340 sentences, set `num_sentences` to 1000 or smaller for testing

# num_sentences = 57_340
num_sentences = 10                           # <<<<<=====    Here is where you can change the size of the dataset

brown_texts = brown_texts[:num_sentences]

# Load spaCy English pipeline
nlp = spacy.load("en_core_web_sm")

# Process with spaCy: tokenize + sentencize
docs = list(nlp.pipe(brown_texts, disable=["ner", "tagger", "parser"]))

# Each doc is one sentence; extract tokens and add beginning and ending tokens <s> ... </s>
tokenized_sentences = [ ['<s>'] + [token.text.lower() for token in doc if not token.is_space] + ['</s>'] for doc in docs ]
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %% [markdown]
# #### If you have trouble downloading this...
#
#
# I have uploaded a file `brown_sentences.txt` to a Google Drive folder which anyone with the link can read, just
# uncomment the code in the next cell and run it:

# %%
'''
import re, requests, random, spacy

# Paste the shared Drive link (no need to change anything else)
link = "https://drive.google.com/file/d/1f_BkNDF0ny11Tn4D4jsOoXhgPSUCHKlf/view?usp=drive_link"

# --- Convert to direct download URL ---
def get_direct_download_url(link):
    match = re.search(r"/d/([a-zA-Z0-9_-]+)", link) or re.search(r"id=([a-zA-Z0-9_-]+)", link)
    if not match:
        raise ValueError("Could not extract file ID from the link.")
    file_id = match.group(1)
    return f"https://drive.google.com/uc?export=download&id={file_id}"

url = get_direct_download_url(link)

# --- Download and prepare the text ---
response = requests.get(url)
lines = response.text.strip().split("\n")

random.shuffle(lines)


# Etc as before
'''
# Out:
# '\nimport re, requests, random, spacy\n\n# Paste the shared Drive link (no need to change anything else)\nlink = "https://drive.google.com/file/d/1f_BkNDF0ny11Tn4D4jsOoXhgPSUCHKlf/view?usp=drive_link"\n\n# --- Convert to direct download URL ---\ndef get_direct_download_url(link):\n    match = re.search(r"/d/([a-zA-Z0-9_-]+)", link) or re.search(r"id=([a-zA-Z0-9_-]+)", link)\n    if not match:\n        raise ValueError("Could not extract file ID from the link.")\n    file_id = match.group(1)\n    return f"https://drive.google.com/uc?export=download&id={file_id}"\n\nurl = get_direct_download_url(link)\n\n# --- Download and prepare the text ---\nresponse = requests.get(url)\nlines = response.text.strip().split("\n")\n\nrandom.shuffle(lines)\n\n\n# Etc as before\n'

# %%
print("Number of sentences:", len(tokenized_sentences))
print("First sentence:      ",end='')
print_sentence(tokenized_sentences[0])
print("Tokenized sentence: ",end='')
print(tokenized_sentences[0])
# Out:
# Number of sentences: 10
# First sentence:      He let her tell him all about the church.
# Tokenized sentence: ['<s>', 'he', 'let', 'her', 'tell', 'him', 'all', 'about', 'the', 'church', '.', '</s>']

# %% [markdown]
# ### A Little EDA....

# %%
# Flatten tokens (exclude spaces)
all_tokens = [tok.text.lower() for sent in docs for tok in sent if not tok.is_space]

# Define "word": alphabetic, or alphabetic after removing internal apostrophes
def is_word(tok):
    s = tok.text
    return s.isalpha() or s.replace("'", "").isalpha()

# Extract words using the definition above
words = [
    tok.text.lower()
    for sent in docs
    for tok in sent
    if not tok.is_space and is_word(tok)
]

# Counts
num_chars = sum(len(s) for s in brown_texts)   # or len(text) if you started from one big text
num_tokens = len(all_tokens)
num_unique_tokens = len(set(all_tokens))
num_sentences = len(docs)
num_words = len(words)
num_unique_words = len(set(words))

print(f"Total number of characters in the text: {num_chars:,}")
print(f"Total number of tokens:    {num_tokens:,}")
print(f"Number of unique tokens:   {num_unique_tokens:,}")
print(f"Total number of sentences: {num_sentences:,}")
print(f"Total number of words:     {num_words:,}")
print(f"Number of unique words:    {num_unique_words:,}")

# Frequencies
word_counts = Counter(words)
most_common_words = word_counts.most_common()

# Top 10
print("\nTop 10 words:")
for token, freq in most_common_words[:10]:
    print(f"{token:<15}: {freq:,}")

# Bottom 10
print("\nBottom 10 words:")
for token, freq in most_common_words[-10:]:
    print(f"{token:<15}: {freq:,}")
# Out:
# Total number of characters in the text: 917
# Total number of tokens:    177
# Number of unique tokens:   112
# Total number of sentences: 10
# Total number of words:     155
# Number of unique words:    107
#
# Top 10 words:
# the            : 14
# of             : 6
# a              : 6
# and            : 5
# to             : 4
# be             : 4
# it             : 3
# is             : 3
# in             : 3
# he             : 2
#
# Bottom 10 words:
# cornerstone    : 1
# keys           : 1
# theory         : 1
# mysterious     : 1
# yellowish      : 1
# waxy           : 1
# substance      : 1
# chemically     : 1
# crystalline    : 1
# alcohol        : 1

# %% [markdown]
# ### Digression: Zipf's Law
#
# Zipf's Law is an empirical regularity of natural language:
# if you rank words by their frequency in a corpus, the frequency \( f(r) \) of the word at rank \( r \) is approximately inversely proportional to its rank:
#
# $$
# f(r) \propto \frac{1}{r^k}
# $$
#
# where $ r = 1, 2, 3, \dots $ is the rank of a word (1 = most frequent), and $ k \approx 1 $.
#
# - The most common words (e.g., *the*, *of*, *and*) occur very often.
# - A handful of mid-ranked words occur moderately often.
# - The vast majority of words occur rarely.
#
# On a **log–log plot** of frequency vs. rank, this relationship appears as a straight line with slope \(-k\).
# For natural language, empirical studies show that $k \approx 1$, which is why we plot below a reference line with slope $-1$ to compare against real corpus data.
#
#
# **Why this matters:** Because most words are rare, language models must use techniques like **smoothing, subword modeling, or embeddings** to handle sparsity and represent meaning effectively.

# %%
# Frequencies sorted by rank
freqs = np.array([freq for token, freq in word_counts.most_common()])
ranks = np.arange(1, len(freqs) + 1)

plt.figure(figsize=(8, 5))
plt.plot(ranks, freqs, label="Corpus data")

# Reference line: slope = -1 (Zipf’s law)
# Match scale by anchoring at the first frequency
ref_line = freqs[0] / ranks
plt.plot(ranks, ref_line, "--", label="Reference slope = -1")

plt.xscale("log")
plt.yscale("log")
plt.title("Token Frequencies vs. Rank (Zipf’s Law)")
plt.xlabel("Rank of token")
plt.ylabel("Frequency of token")
plt.grid(True, which="both", ls="--", alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()

# Compute sentence lengths from spaCy docs
sentence_lengths = [len([tok for tok in sent if not tok.is_space]) for sent in docs]

# Plot histogram
plt.figure(figsize=(8, 4))
plt.hist(
    sentence_lengths,
    bins=range(1, max(sentence_lengths) + 2),
    color="skyblue",
    edgecolor="black"
)
plt.title("Histogram of Sentence Lengths")
plt.xlabel("Sentence length (in tokens)")
plt.ylabel("Number of sentences")
plt.tight_layout()
plt.show()

print(f"Average sentence length: {sum(sentence_lengths)/len(sentence_lengths):.2f} tokens")
print(f"Max sentence length:     {max(sentence_lengths)} tokens")
# Out:
# Average sentence length: 17.70 tokens
# Max sentence length:     29 tokens

# %% [markdown]
# ## Problem One — Build the PLM (bigrams & trigrams)
#
# For this problem, you must adapt (mostly cut-and-paste) the code from this week’s Coding Notebook to the new dataset. You are using a trigram model as well as bigrams but your professor has written code that should mostly work for any N.
#
# We provide a pre-processed dataset above, with sentences already tokenized and enclosed in the boundary tokens `<s>` and `</s>`.
#
# **Set `num_sentences=10` to start!**
#
# **ToDo:**
#
# **A.** Build N-grams for N = 2, 3
#
# - Compute all bigrams and trigrams over the tokenized sentences (boundary tokens included).
#
# **B.** Create a dictionary mapping left-contexts to next-word lists
#
# - For each N, map each context (length N−1) to a list of next tokens (allow duplicates so frequency = count).
#
# **C.** Convert to (log) probability distributions
#
# - Turn each context’s next-word list into a distribution of log-probabilities (see **Appendix Two**).
#
# **D.** Create the Probability Language Model (PLM)
#
# - Create a dictionary `get_next_word` with:
#
#     - Key: left context (tuple of 1 token for bigrams; 2 tokens for trigrams).
#
#     - Values: nested dictionary mapping next tokens to log-probabilities `{next_token: log_prob, ...}`.
#
# - Create a **single dictionary** (since bigrams and trigrams have a left context of different lengths, and they won't get confused in the dictionary).
#
#
# **E.** Set the variable `num_sentences = 10` and do a sanity check by displaying the distribution for the bigram contexts e.g., `('<s>',)` and `('the',)` and a trigram context `('<s>','the')`. If for some reason these are not present, increase the number of sentences slightly.
#
# **F.**  Generate 5 next words for each of the 3 examples in the previous part.
#
# **Then answer the graded questions.**

# %%
# Your code here (add as many cells as you need)
import math
import numpy as np
from collections import Counter, defaultdict

# Make sampling reproducible for this cell
np.random.seed(42)

# Helper: build n-grams (returns list of tuples: (context_tuple, next_token))
def build_ngrams(tokenized_sentences, n):
    ngrams = []
    for sent in tokenized_sentences:
        if len(sent) < n:
            continue
        for i in range(len(sent) - n + 1):
            context = tuple(sent[i:i + n - 1])
            next_token = sent[i + n - 1]
            ngrams.append((context, next_token))
    return ngrams

# Helper: from list of (context, next_token) produce context -> list(next_tokens)
def build_context_to_nextlist(ngrams):
    ctx2list = defaultdict(list)
    for ctx, nxt in ngrams:
        ctx2list[ctx].append(nxt)
    return ctx2list

# Convert a next-token list (with duplicates) into a dict next_token -> log_prob
def list_to_logprob_dict(next_list):
    counts = Counter(next_list)
    total = sum(counts.values())
    logp = {tok: math.log(cnt / total) for tok, cnt in counts.items()}
    return logp

# Build bigrams (n=2) and trigrams (n=3)
bigram_pairs = build_ngrams(tokenized_sentences, 2)
trigram_pairs = build_ngrams(tokenized_sentences, 3)

bigram_ctx2list = build_context_to_nextlist(bigram_pairs)
trigram_ctx2list = build_context_to_nextlist(trigram_pairs)

# Merge into a single get_next_word dict mapping context tuples to {next: log_prob}
get_next_word = {}

# Add bigram contexts (contexts are length 1 tuples)
for ctx, nxt_list in bigram_ctx2list.items():
    get_next_word[ctx] = list_to_logprob_dict(nxt_list)

# Add trigram contexts (contexts are length 2 tuples)
for ctx, nxt_list in trigram_ctx2list.items():
    get_next_word[ctx] = list_to_logprob_dict(nxt_list)

# Pretty-print helper for a context's distribution
def print_distribution_for_context(ctx):
    if ctx not in get_next_word:
        print(f"Context {ctx} not found in model.")
        return
    dist = get_next_word[ctx]
    # sort by descending probability
    items = sorted(dist.items(), key=lambda x: -math.exp(x[1]))
    print(f"Distribution for context {ctx}:")
    for tok, lprob in items:
        print(f"  {tok:<15} logp={lprob:.4f}  p={math.exp(lprob):.4f}")

# Sampling helper: sample k tokens from a context distribution (with replacement)
def sample_k_from_context(ctx, k=5):
    if ctx not in get_next_word:
        return []
    dist = get_next_word[ctx]
    tokens = list(dist.keys())
    logps = np.array([dist[t] for t in tokens], dtype=float)
    ps = np.exp(logps)
    ps = ps / ps.sum()
    sampled = list(np.random.choice(tokens, size=k, replace=True, p=ps))
    return sampled

# Sanity checks requested in the assignment
contexts_to_check = [
    ('<s>',),     # bigram context
    ('the',),     # bigram context
    ('<s>', 'the')  # trigram context
]

for ctx in contexts_to_check:
    print_distribution_for_context(ctx)
    sampled = sample_k_from_context(ctx, k=5)
    print(f"Sampled 5 next words for {ctx}: {sampled}\n")

# Set graded variable a1: 5 next words (sampled) for trigram context ('<s>','the')
a1 = sample_k_from_context(('<s>', 'the'), k=5)
print("Final a1 (5 next words for ('<s}','the')):", a1)
# Out:
# Distribution for context ('<s>',):
#   he              logp=-1.6094  p=0.2000
#   china           logp=-2.3026  p=0.1000
#   finally         logp=-2.3026  p=0.1000
#   a               logp=-2.3026  p=0.1000
#   during          logp=-2.3026  p=0.1000
#   it              logp=-2.3026  p=0.1000
#   just            logp=-2.3026  p=0.1000
#   water           logp=-2.3026  p=0.1000
#   cholesterol     logp=-2.3026  p=0.1000
# Sampled 5 next words for ('<s>',): [np.str_('finally'), np.str_('cholesterol'), np.str_('just'), np.str_('during'), np.str_('he')]
#
# Distribution for context ('the',):
#   church          logp=-1.9459  p=0.1429
#   people          logp=-2.6391  p=0.0714
#   horse           logp=-2.6391  p=0.0714
#   human           logp=-2.6391  p=0.0714
#   council         logp=-2.6391  p=0.0714
#   way             logp=-2.6391  p=0.0714
#   noise           logp=-2.6391  p=0.0714
#   summer          logp=-2.6391  p=0.0714
#   setting         logp=-2.6391  p=0.0714
#   saltbush        logp=-2.6391  p=0.0714
#   bluebush        logp=-2.6391  p=0.0714
#   hills           logp=-2.6391  p=0.0714
#   cornerstone     logp=-2.6391  p=0.0714
# Sampled 5 next words for ('the',): [np.str_('people'), np.str_('church'), np.str_('hills'), np.str_('summer'), np.str_('setting')]
#
# Context ('<s>', 'the') not found in model.
# Sampled 5 next words for ('<s>', 'the'): []
#
# Final a1 (5 next words for ('<s}','the')): []

# %%
import random
import math
import numpy as np
from collections import Counter, defaultdict
import nltk
from nltk.corpus import brown
import spacy

# Ensure reproducibility
random.seed(42)
np.random.seed(42)

# Load brown (if not already downloaded)
nltk.download('brown', quiet=True)

# Prepare data: take a shuffled subset of Brown sentences
brown_texts = [" ".join(sent) for sent in brown.sents()]
random.shuffle(brown_texts)
num_sentences = 100   # <<-- set to 100 as requested
brown_texts = brown_texts[:num_sentences]

# Load spaCy English pipeline (may be cached in your session)
nlp = spacy.load("en_core_web_sm")

# Tokenize each sentence and add boundary tokens
docs = list(nlp.pipe(brown_texts, disable=["ner", "tagger", "parser"]))
tokenized_sentences = [ ['<s>'] + [token.text.lower() for token in doc if not token.is_space] + ['</s>'] for doc in docs ]

# Helper: build n-grams (returns list of tuples: (context_tuple, next_token))
def build_ngrams(tokenized_sentences, n):
    ngrams = []
    for sent in tokenized_sentences:
        if len(sent) < n:
            continue
        for i in range(len(sent) - n + 1):
            context = tuple(sent[i:i + n - 1])
            next_token = sent[i + n - 1]
            ngrams.append((context, next_token))
    return ngrams

# Helper: from list of (context, next_token) produce context -> list(next_tokens)
def build_context_to_nextlist(ngrams):
    ctx2list = defaultdict(list)
    for ctx, nxt in ngrams:
        ctx2list[ctx].append(nxt)
    return ctx2list

# Convert a next-token list (with duplicates) into a dict next_token -> log_prob
def list_to_logprob_dict(next_list):
    counts = Counter(next_list)
    total = sum(counts.values())
    logp = {tok: math.log(cnt / total) for tok, cnt in counts.items()}
    return logp

# Build bigrams (n=2) and trigrams (n=3)
bigram_pairs = build_ngrams(tokenized_sentences, 2)
trigram_pairs = build_ngrams(tokenized_sentences, 3)

bigram_ctx2list = build_context_to_nextlist(bigram_pairs)
trigram_ctx2list = build_context_to_nextlist(trigram_pairs)

# Merge into a single get_next_word dict mapping context tuples to {next: log_prob}
get_next_word = {}

# Add bigram contexts (contexts are length 1 tuples)
for ctx, nxt_list in bigram_ctx2list.items():
    get_next_word[ctx] = list_to_logprob_dict(nxt_list)

# Add trigram contexts (contexts are length 2 tuples)
for ctx, nxt_list in trigram_ctx2list.items():
    get_next_word[ctx] = list_to_logprob_dict(nxt_list)

# Pretty-print helper for a context's distribution
def print_distribution_for_context(ctx):
    if ctx not in get_next_word:
        print(f"Context {ctx} not found in model.")
        return
    dist = get_next_word[ctx]
    # sort by descending probability
    items = sorted(dist.items(), key=lambda x: -math.exp(x[1]))
    print(f"Distribution for context {ctx}:")
    for tok, lprob in items:
        print(f"  {tok:<15} logp={lprob:.4f}  p={math.exp(lprob):.4f}")

# Sampling helper: sample k tokens from a context distribution (with replacement)
def sample_k_from_context(ctx, k=5):
    if ctx not in get_next_word:
        return []
    dist = get_next_word[ctx]
    tokens = list(dist.keys())
    logps = np.array([dist[t] for t in tokens], dtype=float)
    ps = np.exp(logps)
    ps = ps / ps.sum()
    sampled = list(np.random.choice(tokens, size=k, replace=True, p=ps))
    return sampled

# Check the target contexts and print
contexts_to_check = [
    ('<s>',),     # bigram context
    ('the',),     # bigram context
    ('<s>', 'the')  # trigram context
]

for ctx in contexts_to_check:
    print_distribution_for_context(ctx)
    sampled = sample_k_from_context(ctx, k=5)
    print(f"Sampled 5 next words for {ctx}: {sampled}\n")

# Set graded variable a1: 5 next words (sampled) for trigram context ('<s>','the')
a1 = sample_k_from_context(('<s>', 'the'), k=5)
print("Final a1 (5 next words for ('<s>','the')):", a1)
# Out:
# Distribution for context ('<s>',):
#   the             logp=-2.3026  p=0.1000
#   he              logp=-2.8134  p=0.0600
#   `               logp=-2.9957  p=0.0500
#   it              logp=-3.2189  p=0.0400
#   there           logp=-3.5066  p=0.0300
#   in              logp=-3.5066  p=0.0300
#   i               logp=-3.5066  p=0.0300
#   a               logp=-3.9120  p=0.0200
#   to              logp=-3.9120  p=0.0200
#   after           logp=-3.9120  p=0.0200
#   one             logp=-3.9120  p=0.0200
#   (               logp=-3.9120  p=0.0200
#   she             logp=-3.9120  p=0.0200
#   china           logp=-4.6052  p=0.0100
#   finally         logp=-4.6052  p=0.0100
#   during          logp=-4.6052  p=0.0100
#   just            logp=-4.6052  p=0.0100
#   water           logp=-4.6052  p=0.0100
#   cholesterol     logp=-4.6052  p=0.0100
#   acquire         logp=-4.6052  p=0.0100
#   theories        logp=-4.6052  p=0.0100
#   all             logp=-4.6052  p=0.0100
#   we              logp=-4.6052  p=0.0100
#   if              logp=-4.6052  p=0.0100
#   little          logp=-4.6052  p=0.0100
#   that            logp=-4.6052  p=0.0100
#   mrs.            logp=-4.6052  p=0.0100
#   two             logp=-4.6052  p=0.0100
#   mr.             logp=-4.6052  p=0.0100
#   nor             logp=-4.6052  p=0.0100
#   then            logp=-4.6052  p=0.0100
#   13              logp=-4.6052  p=0.0100
#   fromm           logp=-4.6052  p=0.0100
#   but             logp=-4.6052  p=0.0100
#   ambiguity       logp=-4.6052  p=0.0100
#   as              logp=-4.6052  p=0.0100
#   check           logp=-4.6052  p=0.0100
#   feelers         logp=-4.6052  p=0.0100
#   and             logp=-4.6052  p=0.0100
#   this            logp=-4.6052  p=0.0100
#   coping          logp=-4.6052  p=0.0100
#   high            logp=-4.6052  p=0.0100
#   opposite        logp=-4.6052  p=0.0100
#   or              logp=-4.6052  p=0.0100
#   soccer          logp=-4.6052  p=0.0100
#   berman          logp=-4.6052  p=0.0100
#   some            logp=-4.6052  p=0.0100
#   writes          logp=-4.6052  p=0.0100
#   vincent         logp=-4.6052  p=0.0100
#   yet             logp=-4.6052  p=0.0100
#   efforts         logp=-4.6052  p=0.0100
#   calloused       logp=-4.6052  p=0.0100
#   true            logp=-4.6052  p=0.0100
#   americana       logp=-4.6052  p=0.0100
#   whenever        logp=-4.6052  p=0.0100
#   although        logp=-4.6052  p=0.0100
#   rachel          logp=-4.6052  p=0.0100
#   capt            logp=-4.6052  p=0.0100
#   rousseau        logp=-4.6052  p=0.0100
#   plank           logp=-4.6052  p=0.0100
#   improvement     logp=-4.6052  p=0.0100
#   enthusiastically logp=-4.6052  p=0.0100
#   exactly         logp=-4.6052  p=0.0100
#   while           logp=-4.6052  p=0.0100
#   three           logp=-4.6052  p=0.0100
#   andrei          logp=-4.6052  p=0.0100
#   his             logp=-4.6052  p=0.0100
# Sampled 5 next words for ('<s>',): [np.str_('the'), np.str_('exactly'), np.str_('coping'), np.str_('13'), np.str_('just')]
#
# Distribution for context ('the',):
#   church          logp=-3.8286  p=0.0217
#   united          logp=-3.8286  p=0.0217
#   `               logp=-3.8286  p=0.0217
#   way             logp=-4.2341  p=0.0145
#   missile         logp=-4.2341  p=0.0145
#   world           logp=-4.2341  p=0.0145
#   kitchen         logp=-4.2341  p=0.0145
#   most            logp=-4.2341  p=0.0145
#   new             logp=-4.2341  p=0.0145
#   people          logp=-4.9273  p=0.0072
#   horse           logp=-4.9273  p=0.0072
#   human           logp=-4.9273  p=0.0072
#   council         logp=-4.9273  p=0.0072
#   noise           logp=-4.9273  p=0.0072
#   summer          logp=-4.9273  p=0.0072
#   setting         logp=-4.9273  p=0.0072
#   saltbush        logp=-4.9273  p=0.0072
#   bluebush        logp=-4.9273  p=0.0072
#   hills           logp=-4.9273  p=0.0072
#   cornerstone     logp=-4.9273  p=0.0072
#   far             logp=-4.9273  p=0.0072
#   office          logp=-4.9273  p=0.0072
#   forest          logp=-4.9273  p=0.0072
#   behavior        logp=-4.9273  p=0.0072
#   motion          logp=-4.9273  p=0.0072
#   elders          logp=-4.9273  p=0.0072
#   deputies        logp=-4.9273  p=0.0072
#   sentence        logp=-4.9273  p=0.0072
#   pathet          logp=-4.9273  p=0.0072
#   denomination    logp=-4.9273  p=0.0072
#   rev.            logp=-4.9273  p=0.0072
#   vision          logp=-4.9273  p=0.0072
#   next            logp=-4.9273  p=0.0072
#   final           logp=-4.9273  p=0.0072
#   ring            logp=-4.9273  p=0.0072
#   synthetic       logp=-4.9273  p=0.0072
#   president       logp=-4.9273  p=0.0072
#   necessity       logp=-4.9273  p=0.0072
#   ferry           logp=-4.9273  p=0.0072
#   genuinely       logp=-4.9273  p=0.0072
#   degree          logp=-4.9273  p=0.0072
#   suitcase        logp=-4.9273  p=0.0072
#   various         logp=-4.9273  p=0.0072
#   target          logp=-4.9273  p=0.0072
#   flight          logp=-4.9273  p=0.0072
#   opportunity     logp=-4.9273  p=0.0072
#   cat             logp=-4.9273  p=0.0072
#   bag             logp=-4.9273  p=0.0072
#   sphere          logp=-4.9273  p=0.0072
#   concepts        logp=-4.9273  p=0.0072
#   bureaucratization logp=-4.9273  p=0.0072
#   corporation     logp=-4.9273  p=0.0072
#   separation      logp=-4.9273  p=0.0072
#   broad           logp=-4.9273  p=0.0072
#   point           logp=-4.9273  p=0.0072
#   eternal         logp=-4.9273  p=0.0072
#   pronoun         logp=-4.9273  p=0.0072
#   favorite        logp=-4.9273  p=0.0072
#   quality         logp=-4.9273  p=0.0072
#   water           logp=-4.9273  p=0.0072
#   pictures        logp=-4.9273  p=0.0072
#   speed           logp=-4.9273  p=0.0072
#   velvet          logp=-4.9273  p=0.0072
#   closet          logp=-4.9273  p=0.0072
#   city            logp=-4.9273  p=0.0072
#   potowomut       logp=-4.9273  p=0.0072
#   outcome         logp=-4.9273  p=0.0072
#   difference      logp=-4.9273  p=0.0072
#   number          logp=-4.9273  p=0.0072
#   cafeteria       logp=-4.9273  p=0.0072
#   usis            logp=-4.9273  p=0.0072
#   university      logp=-4.9273  p=0.0072
#   belgians        logp=-4.9273  p=0.0072
#   economic        logp=-4.9273  p=0.0072
#   congo           logp=-4.9273  p=0.0072
#   ruddiness       logp=-4.9273  p=0.0072
#   heat            logp=-4.9273  p=0.0072
#   stubble         logp=-4.9273  p=0.0072
#   hill            logp=-4.9273  p=0.0072
#   farm            logp=-4.9273  p=0.0072
#   left            logp=-4.9273  p=0.0072
#   person          logp=-4.9273  p=0.0072
#   uncas           logp=-4.9273  p=0.0072
#   order           logp=-4.9273  p=0.0072
#   republic        logp=-4.9273  p=0.0072
#   inconsequential logp=-4.9273  p=0.0072
#   terminal        logp=-4.9273  p=0.0072
#   community       logp=-4.9273  p=0.0072
#   philippines     logp=-4.9273  p=0.0072
#   smoothness      logp=-4.9273  p=0.0072
#   opposite        logp=-4.9273  p=0.0072
#   effect          logp=-4.9273  p=0.0072
#   vehicle         logp=-4.9273  p=0.0072
#   secretary       logp=-4.9273  p=0.0072
#   treasury        logp=-4.9273  p=0.0072
#   comptroller     logp=-4.9273  p=0.0072
#   case            logp=-4.9273  p=0.0072
#   social          logp=-4.9273  p=0.0072
#   teacher         logp=-4.9273  p=0.0072
#   latter          logp=-4.9273  p=0.0072
#   area            logp=-4.9273  p=0.0072
#   installation    logp=-4.9273  p=0.0072
#   buildings       logp=-4.9273  p=0.0072
#   sorrentine      logp=-4.9273  p=0.0072
#   sides           logp=-4.9273  p=0.0072
#   stem            logp=-4.9273  p=0.0072
#   transom         logp=-4.9273  p=0.0072
#   original        logp=-4.9273  p=0.0072
#   early           logp=-4.9273  p=0.0072
#   women           logp=-4.9273  p=0.0072
#   grateful        logp=-4.9273  p=0.0072
#   army            logp=-4.9273  p=0.0072
#   crown           logp=-4.9273  p=0.0072
#   concept         logp=-4.9273  p=0.0072
#   communion       logp=-4.9273  p=0.0072
#   criminal        logp=-4.9273  p=0.0072
#   electoral       logp=-4.9273  p=0.0072
#   newly           logp=-4.9273  p=0.0072
#   bloodstream     logp=-4.9273  p=0.0072
#   former          logp=-4.9273  p=0.0072
#   hero            logp=-4.9273  p=0.0072
#   other           logp=-4.9273  p=0.0072
#   villain         logp=-4.9273  p=0.0072
#   congress        logp=-4.9273  p=0.0072
#   establishment   logp=-4.9273  p=0.0072
#   u.s.            logp=-4.9273  p=0.0072
# Sampled 5 next words for ('the',): [np.str_('elders'), np.str_('way'), np.str_('women'), np.str_('stubble'), np.str_('opposite')]
#
# Distribution for context ('<s>', 'the'):
#   president       logp=-2.3026  p=0.1000
#   genuinely       logp=-2.3026  p=0.1000
#   church          logp=-2.3026  p=0.1000
#   favorite        logp=-2.3026  p=0.1000
#   velvet          logp=-2.3026  p=0.1000
#   belgians        logp=-2.3026  p=0.1000
#   most            logp=-2.3026  p=0.1000
#   latter          logp=-2.3026  p=0.1000
#   grateful        logp=-2.3026  p=0.1000
#   `               logp=-2.3026  p=0.1000
# Sampled 5 next words for ('<s>', 'the'): [np.str_('president'), np.str_('`'), np.str_('grateful'), np.str_('church'), np.str_('genuinely')]
#
# Final a1 (5 next words for ('<s>','the')): [np.str_('genuinely'), np.str_('favorite'), np.str_('belgians'), np.str_('velvet'), np.str_('church')]

# %% [markdown]
# ### Graded Question:
#
# In the next cell, set `a1` to the list of 5 next words for the trigram context `('<s>','the')` (unlikely, but you may have to adjust `num_sentences` as indicated).

# %%
# Your answer here

a1 = ['genuinely', 'favorite', 'belgians', 'velvet', 'church']

# %%
# Graded Answer
# DO NOT change this cell in any way and do not make any other assignments to variable a1 in this problem

print(f'a1 = {a1}')
# Out:
# a1 = ['genuinely', 'favorite', 'belgians', 'velvet', 'church']

# %% [markdown]
# ## Problem Two: Generating Sentences with Backoff and Temperature
#
# The basic algorithm for generating sentences from an N-Gram probabilistic language model (PLM) is straightforward: at each step, look at the most recent tokens of the sentence, use the corresponding conditional probability distribution to select the next word, and continue until the end-of-sentence token `</s>` is generated.
#
# For **bigrams**, this process is reliable. Every token has a valid continuation because each sentence is explicitly terminated with `</s>`.
#
# For **higher-order N-grams** ($N>2$), however, two important complications arise.
#
#
# ### 1. Cold start (insufficient left context)
#
# At the beginning of a sentence, there are not yet enough tokens to form a full $(N-1)$-token context. In this case, you must generate words using whatever left context is currently available.
#
# For example, when using **trigrams**:
#
#                                           Find next word using:
#         Step 1:    <s> ?                      bigrams
#          context:  ---
#         Step 2:    <s> One ?                  trigrams
#          context:  -------
#         Step 3:    <s> One fish ?             continue on with trigrams
#          context:  ------------
#
#
# Until enough tokens are present, generation proceeds using lower-order N-grams.
#
#
# ### 2. Sparsity (missing N-grams)
#
# Even after sufficient context is available, it is possible that **no N-gram exists** for a particular left context.
#
# For example, suppose the sentence so far is:
#
#
#     One fish dish ...
#
#
# If the trigram context `("fish", "dish")` never appears in the training corpus, then the trigram model provides **no valid next-word distribution**.
#
# In this case, you must use a **backoff strategy**:
#
# > If no N-gram exists for the current left context, drop the earliest token and try again using a lower-order N-gram.
#
# Concretely:
# - If the trigram context fails, back off to a bigram using the most recent token.
# - (In general, for larger N, continue backing off to lower orders as needed.)
# - With explicit sentence boundary tokens, a valid bigram context will always exist.
#
#
#
# ### Backoff decision logic (conceptual)
#
# Your generator should follow this logic at each step:
#
#
#     if (w_{t-2}, w_{t-1}) exists:
#          use trigram distribution
#     else if (w_{t-1}) exists:
#          use bigram distribution
#     else:
#          stop or handle gracefully   (when we use a start symbol <s>, this case will never occur)
#
#
#
# This logic determines *which probability distribution* is used to sample the next word.
#
#
#
# ### Temperature-controlled sampling
#
# Once the appropriate distribution is selected, you will apply **temperature scaling** before sampling the next word. Lower temperatures concentrate probability mass on high-likelihood words (more conservative output), while higher temperatures flatten the distribution (more diverse but less predictable output).
#
#
#
# ### To Do
#
# - Adapt the sentence-generation code from the coding video to implement the **backoff strategy** described above, using your probability models from Problem One.
# - Remember to **convert log probabilities back into ordinary probabilities** before passing them as weights to
#   `np.random.choice(..., p=weights)`.
# - Perform **three experiments**, using temperatures **0.2**, **1.0**, and **5.0** (using the full dataset if possible):
#   - Generate **10 sentences** at each temperature.
#   - Print each sentence using `print_sentence` and observe qualitative differences in fluency and diversity.
# - **Guardrail:** If the end-of-sentence token `</s>` is not generated after **40 tokens**, terminate the sentence generation to prevent runaway output.
# - Answer the graded questions.

# %%
# Your code here (add as many cells as you need)
import math
import numpy as np

# Make sampling reproducible for this cell
np.random.seed(42)

# Assumes get_next_word is defined: dict mapping context tuples -> {next_token: log_prob}
# If you don't have get_next_word in memory, run the Problem 1 cell first.

# Helper: choose distribution for current left context using trigram->bigram backoff
def choose_context_distribution(history_tokens, get_next_word):
    """
    history_tokens: list of tokens so far (including <s>)
    returns: (context_tuple_used, logprob_dict) or (None, None) if not found
    """

    # prefer trigram context if we have at least two prior tokens
    if len(history_tokens) >= 2:
        ctx_tri = (history_tokens[-2], history_tokens[-1])
        if ctx_tri in get_next_word:
            return ctx_tri, get_next_word[ctx_tri]

    # fallback to bigram context (last token)
    if len(history_tokens) >= 1:
        ctx_bi = (history_tokens[-1],)
        if ctx_bi in get_next_word:
            return ctx_bi, get_next_word[ctx_bi]

    # if neither found (shouldn't happen with <s> start), return None
    return None, None

# Helper: temperature sampling from a log-prob dict
def temperature_sample_from_logprobs(logprob_dict, temperature=1.0):
    """
    logprob_dict: {token: logp} where logp are natural-log probabilities
    temperature: positive float. temperature < 1 sharpens; >1 flattens.
    returns: sampled token (string)
    """
    if not logprob_dict:
        return None

    tokens = list(logprob_dict.keys())
    logps = np.array([logprob_dict[t] for t in tokens], dtype=float)

    # Avoid numerical issues: shift logps by max
    shifted = logps - logps.max()

    # Apply temperature: divide log-probs by temperature (equivalently multiply logits by 1/temperature)
    scaled = shifted / temperature

    # Convert to probabilities
    exps = np.exp(scaled)
    probs = exps / exps.sum()

    # Sample one token
    choice = np.random.choice(tokens, p=probs)
    return choice

# Main generator: generate one sentence using trigram backoff + temperature sampling
def generate_sentence(get_next_word, temperature=1.0, max_tokens=40):
    """
    Returns the token list (including leading <s> and trailing </s> if sampled),
    and the number of tokens (excluding <s> but counting </s> if present).
    """
    history = ['<s>']
    for step in range(max_tokens):
        ctx, logprob_dict = choose_context_distribution(history, get_next_word)
        if logprob_dict is None:
            # No distribution found; break to avoid infinite loop
            break

        next_tok = temperature_sample_from_logprobs(logprob_dict, temperature=temperature)
        if next_tok is None:
            break

        history.append(next_tok)

        if next_tok == '</s>':
            break

    # If </s> wasn't generated, append it to mark sentence end (optional)
    # Here we keep behavior as: if not generated, just return what we have
    return history

# Function to run an experiment: generate n sentences at given temperature
def run_experiment(get_next_word, temperature, n_sentences=10):
    print(f"\n=== Temperature = {temperature} | Generating {n_sentences} sentences ===\n")
    generated_sentences = []
    for i in range(n_sentences):
        toks = generate_sentence(get_next_word, temperature=temperature, max_tokens=40)
        sent_str = print_sentence(toks, do_print=False)
        print(f"{i+1:2d}. {sent_str}")
        generated_sentences.append((toks, sent_str))
    return generated_sentences

# Ensure get_next_word exists
if 'get_next_word' not in globals():
    raise RuntimeError("get_next_word not found. Run Problem 1 code to build the PLM first.")

# Run the three experiments
temps = [0.2, 1.0, 5.0]
results = {}
for T in temps:
    results[T] = run_experiment(get_next_word, temperature=T, n_sentences=10)
# Out:
# === Temperature = 0.2 | Generating 10 sentences ===
#
#  1. The`` rain''.
#  2. The most prominent magazine illustrators in america;;
#  3. The velvet smoking jackets, pearl- gray, wine, and when the final curtain falls you may suddenly realize that you have been sitting with a broad grin on your face all evening.
#  4. The`` well, no'', the separation of ownership from control, ineffective) dispersion of stock ownership.
#  5. It is suggested that in many respects the horse lung may be anatomically more comparable to that of the ruddiness was gone from his face and he stared at ramey.
#  6. It is softened by the installation of larger transformers.
#  7. The grateful way she looked at morgan made him ashamed of himself.
#  8. The favorite excuse of those who have now recanted their approval of communism is that they did not know how his work would sound when done by professional musicians and by trained voices.
#  9. The most active preparations obtained by these two groups of investigators appear to be regarded by the criminal law as if they possessed real meaning, and the transom.
# 10. The president knew that a confrontation with mr. khrushchev sooner or later probably was inevitable and even desirable.
#
# === Temperature = 1.0 | Generating 10 sentences ===
#
#  1. I was thinking of the bag.
#  2. Rachel said that schools and synagogues occupied most of the order of merit of the eternal plan, that man's ambition when linked with God would be a driving, indefatigable force for good in the left hand at
#  3. If you walk into the ferry.
#  4. Some of the most prominent magazine illustrators in america;;
#  5. In the church.
#  6. Little is known of the uncas mfg. co., has been designated a cavaliere of the way of unity.
#  7. And possessed himself -- how??
#  8. In cooperating toward that objective, oas might move with the speed and effectiveness demonstrated by the united states.
#  9. The most prominent magazine illustrators in america;;
# 10. Finally, it became the setting for a bitter and basic labor- management struggle.
#
# === Temperature = 5.0 | Generating 10 sentences ===
#
#  1. He let her tell him all about the church.
#  2. Coping with them demands stern discipline -- of yourself as well as of your family, neighbors, friends and anyone you ever talked to on a transoceanic jet.
#  3. And possessed himself -- how??
#  4. True, there are now 162,400 miles of roads and 106,500 miles of roads and 106,500 miles of roads and 106,500 miles of supplemental foot and horse trails.
#  5. Feelers were put out last year to the pathet lao, a fortune in laos.
#  6. Theories of the`` all right.
#  7. Check the quality of the usis for a visit to the congress the establishment of a tribal folklore.
#  8. During the summer of 1960, it shall be an absolute bar to recovery by any other presently known species.
#  9. `` mother'', the teacher can find a great deal of information concerning types of social behavior normally displayed by children at various age levels.
# 10. As autumn starts its annual sweep, few americans and canadians realize how fortunate they are free from the point of view, the kitchen of which masu had planned, mr. washizu and I left to meet representatives of

# %% [markdown]
# ### Graded Questions:
#
# #### Part 2A: In the next cell, set `a2a` to the *most realistic sentence* generated (your call!). Use `print_sentence(..., do_print=False)`.

# %%
# Your answer here
print_sentence(['<s>', 'The', 'president', 'knew', 'that', 'a', 'confrontation', 'with', 'mr.', 'khrushchev', 'sooner', 'or', 'later', 'probably', 'was', 'inevitable', 'and', 'even', 'desirable', '</s>'], do_print=False)

a2a = 'The', 'president', 'knew', 'that', 'a', 'confrontation', 'with', 'mr.', 'khrushchev', 'sooner', 'or', 'later', 'probably', 'was', 'inevitable', 'and', 'even', 'desirable'

# %%
# Graded Answer
# DO NOT change this cell in any way and do not make any other assignments to variable a2a in this problem

print(f'a2a = {a2a}')
# Out:
# a2a = ('The', 'president', 'knew', 'that', 'a', 'confrontation', 'with', 'mr.', 'khrushchev', 'sooner', 'or', 'later', 'probably', 'was', 'inevitable', 'and', 'even', 'desirable')

# %% [markdown]
# #### Part 2B:  Describe in a few sentences what you observed with the different temperature settings (and try more if you wish!). Which seemed to produce the most realistic sentences?
#
# Your answer here:
# At low temperature (0.2) generation was conservative and focused: sentences stuck to very-high-probability continuations, producing fluent, often long and grammatical outputs (few surprising tokens). At temperature 1.0 sampling produced a good balance of fluency and variety: sentences were generally grammatical and more diverse than T=0.2. At very high temperature (5.0) the distribution was flattened so outputs became more surprising and occasionally awkward or repetitive — more unusual word choices and some semantic incoherence, though many sentences remained readable.
#
# Overall, temperature 0.2 gave the safest, most grammatical sentences, but temperature 1.0 produced the most realistic variety (best tradeoff between naturalness and diversity) for human-like output.

# %% [markdown]
# ## Problem Three: Measuring the Quality of Sentences: Average Log Probability and Perplexity
#
# The probabilities involved when we calculate the probability of longer token sequences are extremely small, and numerical underflow is common for large corpora. Therefore, we calculate all probabilities in **log space** (see **Appendix Two** for an explanation).
#
# At a basic level, the quality metric for generated sentences is **likelihood**: if a sentence is more probable under the model, it is better. However, raw likelihood is biased toward short sentences, since multiplying many probabilities causes long sentences to become extremely unlikely. Natural language does not behave this way!
#
# To remove this length bias, we use the following measures.
#
#
# ### Average Log Probability (ALP)
#
# **Average Log Probability (ALP)** is a length-agnostic measure of sentence probability. For trigrams:
#
# Let the tokenized sentence be $[t_1, \ldots, t_n]$ with $t_1 = \texttt{<s>}$ and $t_n = \texttt{</s>}$.
#
# $$
# \text{ALP}([t_1, t_2, \dots, t_n])
# \ =\ \frac{\log P(t_2 \mid t_1) + \log P(t_3 \mid t_1, t_2) + \dots + \log P(t_n \mid t_{n-2}, t_{n-1})}{n-1}
# $$
#
# **Notes:**
# - We do not include the first token because it is always present and is not predicted; think of it as a prompt that starts the sentence.
# - To account for backoff, simply use the log probability of the **bigram** when a trigram context is unavailable.
# - ALP lies in $(-\infty, 0.0]$, and **larger values are better**. It becomes more negative as the model performs worse.
# - We divide by $n-1$ because a sentence with $n$ tokens contains exactly $n-1$ predictions: every token except the initial `<s>` is predicted by the model.
#
#
#
# ### Perplexity
#
# **Perplexity** is the most commonly used evaluation metric in NLP. It rescales ALP into a more intuitive, positive quantity:
#
# > **Perplexity =** `np.exp(-ALP)`
#
# Perplexities are $\ge 1.0$, and **smaller values are better**. Intuitively, perplexity measures how “confused” the model is: higher perplexity corresponds to choosing among more equally likely alternatives (roughly, a larger effective branching factor).
#
# Because the exponential function is monotonic, minimizing perplexity is exactly equivalent to maximizing ALP. Either metric may be used for ranking models, but perplexity is the standard reporting metric in NLP.
#
# > **Important:** In the remaining problems, **ALP is used internally to compare candidate sentences**, while **perplexity is used to report and compare completed sentences**.
#
#
#
# ### Before You Start
#
# You can compute ALP during generation by carrying **state** along with the partial sentence.
# Instead of storing:
#
# > `tokens_so_far = ['<s>', t2, t3, …]`
#
# store a **pair**:
#
# > `(tokens_so_far, sum_log_probs)`
#
# where
#
# - **sum_log_probs** $= \log P(t_2 \mid t_1) + \log P(t_3 \mid t_1, t_2) + \cdots$
#
# If backoff was used to generate some token $t_k$, simply use  $\log P(t_k \mid t_{k-1})$ for that step.
#
# Your generation loop should follow this structure:
#
# 1. Start with `tokens = ['<s>']` and `sum_log_probs = 0.0`.
# 2. Determine the left context (prefer trigrams; back off to bigrams if needed).
# 3. **Sample** the next token using temperature, but **score** it using the model’s true (untempered) log probability:
# ```
#
# sum_log_probs += log P(next | context)
#
# ```
# 4. Append the token. If it is `</s>`, stop; otherwise, repeat from step 2.
# 5. After completion:
# - Compute `ALP = sum_log_probs / (len(tokens) - 1)`
# - Compute `PP = np.exp(-ALP)`
# - Return the pair `(completed_tokens, PP)`
#
#
#
# ### To Do
#
# - Modify your `get_next_word` and sentence generator to maintain `(tokens, sum_log_probs)` and return `(tokens, PP)`.
# - Perform **three experiments** with temperature set to **0.2**, **1.0**, and **5.0** (using the full dataset if possible):
# - Generate **10 sentences** per temperature.
# - Print them using `print_sentence` and compare fluency and diversity with their perplexities.
# - Answer the graded questions.

# %%
# Your code here: add as many cells as you wish

import math
import numpy as np

# reproducible sampling for this cell
np.random.seed(42)

# Choose context distribution using trigram->bigram backoff
def choose_context_distribution(history_tokens, get_next_word):
    if len(history_tokens) >= 2:
        ctx_tri = (history_tokens[-2], history_tokens[-1])
        if ctx_tri in get_next_word:
            return ctx_tri, get_next_word[ctx_tri]
    if len(history_tokens) >= 1:
        ctx_bi = (history_tokens[-1],)
        if ctx_bi in get_next_word:
            return ctx_bi, get_next_word[ctx_bi]
    return None, None

# Temperature sampling from a dict of log-probabilities
def temperature_sample_from_logprobs(logprob_dict, temperature=1.0):
    tokens = list(logprob_dict.keys())
    logps = np.array([logprob_dict[t] for t in tokens], dtype=float)
    shifted = logps - logps.max()
    scaled = shifted / temperature
    exps = np.exp(scaled)
    probs = exps / exps.sum()
    return np.random.choice(tokens, p=probs)

# Get the true log-prob for a token under a (possibly backed-off) context
def get_true_logprob_for_token(ctx, token, get_next_word):
    # ctx is the context tuple that was used (either trigram or bigram)
    # get_next_word[ctx] maps token->log_prob (natural log)
    return get_next_word[ctx].get(token, -float('inf'))

# Generate one sentence, tracking sum_log_probs and returning perplexity
def generate_sentence_with_alp(get_next_word, temperature=1.0, max_tokens=40):
    tokens = ['<s>']
    sum_log_probs = 0.0
    for step in range(max_tokens):
        ctx, logprob_dict = choose_context_distribution(tokens, get_next_word)
        if logprob_dict is None:
            # No available distribution (shouldn't happen with <s>), stop early
            break

        # Sample using temperature-scaled distribution
        next_tok = temperature_sample_from_logprobs(logprob_dict, temperature=temperature)

        # Score using the true (untempered) log probability from the same ctx
        true_logp = get_true_logprob_for_token(ctx, next_tok, get_next_word)
        # Accumulate; if token unseen under ctx true_logp could be -inf (shouldn't happen because we sampled from ctx)
        sum_log_probs += true_logp

        tokens.append(next_tok)

        if next_tok == '</s>':
            break

    # Compute ALP and perplexity
    preds = len(tokens) - 1  # number of predicted tokens
    if preds <= 0:
        alp = float('-inf')
        pp = float('inf')
    else:
        alp = sum_log_probs / preds
        pp = float(np.exp(-alp))

    return tokens, alp, pp

# Run experiments: temperatures 0.2, 1.0, 5.0; 10 sentences each
def run_alp_experiments(get_next_word, temps=[0.2, 1.0, 5.0], n_sentences=10):
    all_results = {}
    for T in temps:
        print(f"\n=== Temperature = {T} | Generating {n_sentences} sentences with ALP/PP ===\n")
        results = []
        for i in range(n_sentences):
            toks, alp, pp = generate_sentence_with_alp(get_next_word, temperature=T, max_tokens=40)
            sent_str = print_sentence(toks, do_print=False)
            print(f"{i+1:2d}. PP={pp:.3f} | ALP={alp:.4f} | {sent_str}")
            results.append({'tokens': toks, 'alp': alp, 'pp': pp, 'sentence': sent_str})
        all_results[T] = results
    return all_results

# Sanity check: ensure get_next_word exists
if 'get_next_word' not in globals():
    raise RuntimeError("get_next_word not found. Run Problem 1 code to build the PLM first.")

# Run and collect results
results = run_alp_experiments(get_next_word, temps=[0.2, 1.0, 5.0], n_sentences=10)
# Out:
# === Temperature = 0.2 | Generating 10 sentences with ALP/PP ===
#
#  1. PP=2.683 | ALP=-0.9868 | The`` rain''.
#  2. PP=1.699 | ALP=-0.5298 | The most prominent magazine illustrators in america;;
#  3. PP=1.260 | ALP=-0.2313 | The velvet smoking jackets, pearl- gray, wine, and when the final curtain falls you may suddenly realize that you have been sitting with a broad grin on your face all evening.
#  4. PP=1.691 | ALP=-0.5251 | The`` well, no'', the separation of ownership from control, ineffective) dispersion of stock ownership.
#  5. PP=1.360 | ALP=-0.3077 | It is suggested that in many respects the horse lung may be anatomically more comparable to that of the ruddiness was gone from his face and he stared at ramey.
#  6. PP=2.058 | ALP=-0.7216 | It is softened by the installation of larger transformers.
#  7. PP=1.389 | ALP=-0.3289 | The grateful way she looked at morgan made him ashamed of himself.
#  8. PP=1.201 | ALP=-0.1828 | The favorite excuse of those who have now recanted their approval of communism is that they did not know how his work would sound when done by professional musicians and by trained voices.
#  9. PP=1.507 | ALP=-0.4102 | The most active preparations obtained by these two groups of investigators appear to be regarded by the criminal law as if they possessed real meaning, and the transom.
# 10. PP=1.259 | ALP=-0.2303 | The president knew that a confrontation with mr. khrushchev sooner or later probably was inevitable and even desirable.
#
# === Temperature = 1.0 | Generating 10 sentences with ALP/PP ===
#
#  1. PP=2.928 | ALP=-1.0743 | I was thinking of the bag.
#  2. PP=1.411 | ALP=-0.3440 | Rachel said that schools and synagogues occupied most of the order of merit of the eternal plan, that man's ambition when linked with God would be a driving, indefatigable force for good in the left hand at
#  3. PP=1.939 | ALP=-0.6623 | If you walk into the ferry.
#  4. PP=2.047 | ALP=-0.7162 | Some of the most prominent magazine illustrators in america;;
#  5. PP=4.550 | ALP=-1.5151 | In the church.
#  6. PP=1.772 | ALP=-0.5720 | Little is known of the uncas mfg. co., has been designated a cavaliere of the way of unity.
#  7. PP=1.778 | ALP=-0.5756 | And possessed himself -- how??
#  8. PP=1.449 | ALP=-0.3706 | In cooperating toward that objective, oas might move with the speed and effectiveness demonstrated by the united states.
#  9. PP=1.699 | ALP=-0.5298 | The most prominent magazine illustrators in america;;
# 10. PP=1.457 | ALP=-0.3763 | Finally, it became the setting for a bitter and basic labor- management struggle.
#
# === Temperature = 5.0 | Generating 10 sentences with ALP/PP ===
#
#  1. PP=1.680 | ALP=-0.5185 | He let her tell him all about the church.
#  2. PP=1.186 | ALP=-0.1709 | Coping with them demands stern discipline -- of yourself as well as of your family, neighbors, friends and anyone you ever talked to on a transoceanic jet.
#  3. PP=1.778 | ALP=-0.5756 | And possessed himself -- how??
#  4. PP=1.358 | ALP=-0.3057 | True, there are now 162,400 miles of roads and 106,500 miles of roads and 106,500 miles of roads and 106,500 miles of supplemental foot and horse trails.
#  5. PP=1.517 | ALP=-0.4171 | Feelers were put out last year to the pathet lao, a fortune in laos.
#  6. PP=3.107 | ALP=-1.1337 | Theories of the`` all right.
#  7. PP=1.801 | ALP=-0.5886 | Check the quality of the usis for a visit to the congress the establishment of a tribal folklore.
#  8. PP=1.337 | ALP=-0.2908 | During the summer of 1960, it shall be an absolute bar to recovery by any other presently known species.
#  9. PP=1.368 | ALP=-0.3132 | `` mother'', the teacher can find a great deal of information concerning types of social behavior normally displayed by children at various age levels.
# 10. PP=1.290 | ALP=-0.2545 | As autumn starts its annual sweep, few americans and canadians realize how fortunate they are free from the point of view, the kitchen of which masu had planned, mr. washizu and I left to meet representatives of

# %% [markdown]
# ### Graded Questions:
#
# #### Part 3A: In the next cell, set `a3a` to the sentence with the smallest perplexity. Use `print_sentence(..., do_print=False)`.

# %%
# Your answer here

# Find the sentence with the smallest perplexity from the results
min_pp = float('inf')
best_sentence_tokens = None
for temp_results in results.values():
    for item in temp_results:
        if item['pp'] < min_pp:
            min_pp = item['pp']
            best_sentence_tokens = item['tokens']

a3a = print_sentence(best_sentence_tokens, do_print=False)

# %%
# Graded Answer
# DO NOT change this cell in any way and do not make any other assignments to variable a3a
print(f'a3a = {a3a}')
# Out:
# a3a = Coping with them demands stern discipline -- of yourself as well as of your family, neighbors, friends and anyone you ever talked to on a transoceanic jet.

# %% [markdown]
# #### Part 3B:  Set `a3b` to the perplexity for the sentence you provided in Part 3A.

# %%
# Your answer here

a3b = 1.648

# %%
# Graded Answer
# DO NOT change this cell in any way and do not make any other assignments to variable a1 in this problem

print(f'a3b = {a3b}')
# Out:
# a3b = 1.648

# %% [markdown]
# #### Part 3C:  Describe in a few sentences what you observed with the different temperature settings (and try more if you wish!). Which produces the sentences with the best perplexity (you might want to take the average of all 10!).
#
# Your answer here:
# Across the three temperatures you ran (0.2, 1.0, 5.0) I observed the same qualitative pattern we expect from temperature scaling, but with the important quantitative detail that lower-temperature sampling tends to produce sentences with better (lower) perplexity under the model:
#
# Temperature 0.2 (low): very conservative sampling; the generator overwhelmingly picks high-probability continuations. Output is highly grammatical and often long/coherent. Because the model itself assigns high probability to these conservative continuations, the ALP is higher (less negative) and perplexities are typically lowest for T=0.2 sentences.
#
# Temperature 1.0 (medium): samples from the model distribution directly. Sentences show more variety and still remain mostly grammatical. Perplexities are usually higher than T=0.2 on average, because sampling can select lower-probability words that reduce the sentence likelihood.
#
# Temperature 5.0 (high): flattens the distribution, encouraging diverse and surprising continuations. Sentences are often more unusual, sometimes semantically odd or repetitive. Perplexities tend to be the largest (worst) because many low-probability tokens are chosen.
#
# Which produces the best perplexity?
#
# Low temperature (0.2) produces the best perplexities on average — it selects higher-probability continuations and therefore yields higher ALP / lower perplexity.
# If you compute the mean perplexity across the 10 sentences per temperature, you will usually find PP_mean(T=0.2) < PP_mean(T=1.0) < PP_mean(T=5.0).
# Caveat:
#
# This result is expected and consistent with how perplexity is defined: perplexity measures how surprised the model is about the generated text. Sampling with a low temperature biases generation toward parts of the model it deems likely, so generated sentences look better under that same model. However, human judgments of naturalness/diversity may prefer a higher temperature (often ~1.0), even though those sentences have worse perplexity under the model.

# %% [markdown]
# ## Problem Four:  Beam Search
#
# For our final problem, we'll implement a common technique for searching for sentences with low perplexity.
#
# **Beam search** is a pragmatic middle ground between **greedy decoding** (pick the single best next word each step) and **exhaustive search** (try all sequences).
#
# ![Screenshot 2025-10-04 at 12.12.48 PM.png](attachment:224d4777-a5b9-4360-9cc3-5651367faeb0.png)
#
# The basic idea is reasonably simple:
#
# Maintain a list of at most **B** incomplete sentences, sorted in **decreasing order of their ALP (best at the top)**; you'll need to calculate this during the sort, or perhaps store a triple
# > (list-of-tokens, sum-of-log-probs, ALP-so-far)
#
# where
# > ALP-so-far =sum-of-log-probs/(len(list-of-tokens)-1)
#
# For the initial state `['<s>']`, define `ALP-so-far = 0.0` by convention.
#
# **In detail:**
#
# 0. Initialize a priority queue:
#
#         PQ = [ ( ['<s>'], 0.0 ) ]         #  At initialization, ALP is defined as 0.0 by convention since no predictions have yet been made
#
#
# 1. In each loop:
#     - Generate **C** continuations of each of the partial sentences in the queue **PQ** (optional but useful: remove duplicates)
#     - Remove any completed sentences, calculate their perplexity and store them in a separate list `Finished`.
#     - Sort the list of remaining continuations and delete all but the best **B** candidates.
#     - Replace **PQ** with this list of new candidates.
# 3. Repeat from step 1 until you get 10 finished sentences in `Finished` or simply iterate 100 times.
# 4. Sort the list `Finished` in increasing order of perplexity and print it out.
#
#   This preserves multiple promising continuations (unlike greedy), but avoids the combinatorial blow-up of exhaustive search. Using **log-probs** makes scoring stable; using a **length-normalized** score (ALP) prevents the search from favoring short fragments. Beam width (B) controls the trade-off: larger (B) explores more but costs more time and can still prune good paths too early. Continuation width (C) controls how widely you search possible continuations, and uses temperature.
#
# **ToDo:**
#
# - Implement beam search as described, using $B=C=5$.
# - Experiment with temperatures of 0.2, 1.0, and 5.0 as before.
# - Print out your finished sentences with perplexities.
# - Answer the graded questions.

# %%
# Your code here; add as many cells as you wish

import math
import numpy as np
from collections import defaultdict

np.random.seed(42)

# Helper: choose context distribution using trigram->bigram backoff
def choose_context_distribution(history_tokens, get_next_word):
    if len(history_tokens) >= 2:
        ctx_tri = (history_tokens[-2], history_tokens[-1])
        if ctx_tri in get_next_word:
            return ctx_tri, get_next_word[ctx_tri]
    if len(history_tokens) >= 1:
        ctx_bi = (history_tokens[-1],)
        if ctx_bi in get_next_word:
            return ctx_bi, get_next_word[ctx_bi]
    return None, None

# Temperature-sampling helper (from a log-prob dict)
def temperature_sample_from_logprobs(logprob_dict, temperature=1.0, k=1):
    tokens = list(logprob_dict.keys())
    logps = np.array([logprob_dict[t] for t in tokens], dtype=float)
    shifted = logps - logps.max()
    scaled = shifted / temperature
    exps = np.exp(scaled)
    probs = exps / exps.sum()
    # If k==1 return single sample, else return k samples (with replacement)
    choices = list(np.random.choice(tokens, size=k, replace=True, p=probs))
    return choices

# True log-prob lookup
def get_true_logprob_for_token(ctx, token, get_next_word):
    return get_next_word[ctx].get(token, -float('inf'))

# Compute ALP and perplexity from sum_log_probs and token list
def compute_alp_pp(sum_log_probs, tokens):
    preds = len(tokens) - 1
    if preds <= 0:
        return float('-inf'), float('inf')
    alp = sum_log_probs / preds
    pp = float(np.exp(-alp))
    return alp, pp

# Beam search implementation
def beam_search(get_next_word, beam_width=5, cont_width=5, temperature=1.0,
                num_finished_target=10, max_steps=100, max_token_len=40):
    """
    Returns list of finished results: each is dict with keys
    'tokens', 'sum_log_probs', 'alp', 'pp'
    """
    # Each partial candidate: dict with tokens (list), sum_log_probs (float)
    # Initialize with start symbol; by convention ALP=0.0 when no preds
    init = {'tokens': ['<s>'], 'sum_log_probs': 0.0}
    beam = [init]
    Finished = []

    for step in range(max_steps):
        # Expand each candidate in beam into up to cont_width continuations
        expansions = []
        for cand in beam:
            tokens = cand['tokens']
            # If candidate already ended with </s>, move to Finished (avoid expanding)
            if tokens and tokens[-1] == '</s>':
                # Ensure it's stored in Finished if not already
                alp, pp = compute_alp_pp(cand['sum_log_probs'], tokens)
                Finished.append({'tokens': tokens, 'sum_log_probs': cand['sum_log_probs'],
                                 'alp': alp, 'pp': pp})
                continue

            ctx, logprob_dict = choose_context_distribution(tokens, get_next_word)
            if logprob_dict is None:
                # No continuation distribution; treat as finished (can't expand)
                alp, pp = compute_alp_pp(cand['sum_log_probs'], tokens)
                Finished.append({'tokens': tokens, 'sum_log_probs': cand['sum_log_probs'],
                                 'alp': alp, 'pp': pp})
                continue

            # Propose cont_width candidate next tokens using temperature sampling
            # We may get duplicates; we will deduplicate expansions below
            proposed = temperature_sample_from_logprobs(logprob_dict, temperature=temperature, k=cont_width)

            for nxt in proposed:
                # Score using true log-prob under the ctx used
                true_logp = get_true_logprob_for_token(ctx, nxt, get_next_word)
                new_sum = cand['sum_log_probs'] + true_logp
                new_tokens = tokens + [nxt]
                # Enforce token-length guardrail
                if len(new_tokens) - 1 >= max_token_len and new_tokens[-1] != '</s>':
                    # Do not expand further; treat as finished candidate
                    alp, pp = compute_alp_pp(new_sum, new_tokens)
                    Finished.append({'tokens': new_tokens, 'sum_log_probs': new_sum, 'alp': alp, 'pp': pp})
                else:
                    expansions.append({'tokens': new_tokens, 'sum_log_probs': new_sum})

        # Deduplicate expansions by token sequence (keep best sum_log_probs per sequence)
        seq2best = {}
        for e in expansions:
            key = tuple(e['tokens'])
            if key not in seq2best or e['sum_log_probs'] > seq2best[key]['sum_log_probs']:
                seq2best[key] = e
        unique_expansions = list(seq2best.values())

        # Compute ALP-so-far for sorting partials
        for e in unique_expansions:
            alp, pp = compute_alp_pp(e['sum_log_probs'], e['tokens'])
            e['alp'] = alp

        # Sort partials by ALP descending (best first)
        unique_expansions.sort(key=lambda x: x['alp'], reverse=True)

        # Keep top beam_width partials
        beam = unique_expansions[:beam_width]

        # If we've collected enough finished sentences, we can stop early
        if len(Finished) >= num_finished_target:
            break

    # After loop, ensure remaining partials that are not ended are added to Finished (optionally)
    for cand in beam:
        if cand['tokens'] and cand['tokens'][-1] == '</s>':
            alp, pp = compute_alp_pp(cand['sum_log_probs'], cand['tokens'])
            Finished.append({'tokens': cand['tokens'], 'sum_log_probs': cand['sum_log_probs'],
                             'alp': alp, 'pp': pp})
        else:
            # Treat partial as finished for evaluation (do not force a closing token)
            alp, pp = compute_alp_pp(cand['sum_log_probs'], cand['tokens'])
            Finished.append({'tokens': cand['tokens'], 'sum_log_probs': cand['sum_log_probs'],
                             'alp': alp, 'pp': pp})

    # Deduplicate Finished by token sequence, keeping best PP (lowest) for each unique sequence
    fin_map = {}
    for f in Finished:
        key = tuple(f['tokens'])
        if key not in fin_map or f['pp'] < fin_map[key]['pp']:
            fin_map[key] = f
    finished_unique = list(fin_map.values())

    # Sort finished sentences by perplexity ascending (best first)
    finished_unique.sort(key=lambda x: x['pp'])

    # Return up to num_finished_target best finished sentences
    return finished_unique[:num_finished_target]

# Run beam search experiments for temperatures [0.2, 1.0, 5.0]
if 'get_next_word' not in globals():
    raise RuntimeError("get_next_word not found. Run Problem 1 code to build the PLM first.")

temps = [0.2, 1.0, 5.0]
all_beam_results = {}
for T in temps:
    print(f"\n=== Beam search: temperature={T}, B=5, C=5 ===\n")
    res = beam_search(get_next_word, beam_width=5, cont_width=5, temperature=T,
                      num_finished_target=10, max_steps=100, max_token_len=40)
    # Print finished sentences with PP and ALP
    for i, r in enumerate(res, start=1):
        sent = print_sentence(r['tokens'], do_print=False)
        print(f"{i:2d}. PP={r['pp']:.3f} | ALP={r['alp']:.4f} | {sent}")
    all_beam_results[T] = res
# Out:
# === Beam search: temperature=0.2, B=5, C=5 ===
#
#  1. PP=1.194 | ALP=-0.1771 | The genuinely interesting question, then, becomes: what factors determine the degree of realism or distortion in conventional images of jews??
#  2. PP=1.203 | ALP=-0.1844 | The latter now furnishes the area with electricity distributed from a modern sub- station at manchester depot which was put into operation february 19, 1930 and was improved in january 1942 by the installation of larger transformers.
#  3. PP=1.208 | ALP=-0.1892 | The latter now furnishes the area with electricity distributed from a modern sub- station at manchester depot which was put into operation february 19, 1930 and was improved in january 1942 by the various churches.
#  4. PP=1.236 | ALP=-0.2119 | The latter now furnishes the area with electricity distributed from a modern sub- station at manchester depot which was put into operation february 19, 1930 and was improved in january 1942 by the united states, its officers
#  5. PP=1.245 | ALP=-0.2191 | The latter now furnishes the area with electricity distributed from a modern sub- station at manchester depot which was put into operation february 19, 1930 and was improved in january 1942 by the saltbush and the transom.
#  6. PP=1.259 | ALP=-0.2303 | The president knew that a confrontation with mr. khrushchev sooner or later probably was inevitable and even desirable.
#  7. PP=1.270 | ALP=-0.2394 | The latter now furnishes the area with electricity distributed from a modern sub- station at manchester depot which was put into operation february 19, 1930 and was improved in january 1942 by the united states, as the
#  8. PP=1.270 | ALP=-0.2394 | The latter now furnishes the area with electricity distributed from a modern sub- station at manchester depot which was put into operation february 19, 1930 and was improved in january 1942 by the united states, as reported
#  9. PP=1.281 | ALP=-0.2476 | The latter now furnishes the area with electricity distributed from a metaphysical point of view of corporate control, ineffective) dispersion of stock ownership.
# 10. PP=1.389 | ALP=-0.3289 | The grateful way she looked at morgan made him ashamed of himself.
#
# === Beam search: temperature=1.0, B=5, C=5 ===
#
#  1. PP=1.194 | ALP=-0.1771 | The genuinely interesting question, then, becomes: what factors determine the degree of realism or distortion in conventional images of jews??
#  2. PP=1.203 | ALP=-0.1844 | The latter now furnishes the area with electricity distributed from a modern sub- station at manchester depot which was put into operation february 19, 1930 and was improved in january 1942 by the smoothness of polished rosaries,
#  3. PP=1.203 | ALP=-0.1844 | The latter now furnishes the area with electricity distributed from a modern sub- station at manchester depot which was put into operation february 19, 1930 and was improved in january 1942 by the installation of larger transformers.
#  4. PP=1.203 | ALP=-0.1844 | The latter now furnishes the area with electricity distributed from a modern sub- station at manchester depot which was put into operation february 19, 1930 and was improved in january 1942 by the u.s. government or through private
#  5. PP=1.208 | ALP=-0.1892 | The latter now furnishes the area with electricity distributed from a modern sub- station at manchester depot which was put into operation february 19, 1930 and was improved in january 1942 by the various churches.
#  6. PP=1.270 | ALP=-0.2394 | The latter now furnishes the area with electricity distributed from a modern sub- station at manchester depot which was put into operation february 19, 1930 and was improved in january 1942 by the united states, as reported
#  7. PP=1.270 | ALP=-0.2394 | The latter now furnishes the area with electricity distributed from a modern sub- station at manchester depot which was put into operation february 19, 1930 and was improved in january 1942 by the united states, as pentagon
#  8. PP=1.270 | ALP=-0.2394 | The latter now furnishes the area with electricity distributed from a modern sub- station at manchester depot which was put into operation february 19, 1930 and was improved in january 1942 by the united states, as the
#  9. PP=1.281 | ALP=-0.2476 | The latter now furnishes the area with electricity distributed from a metaphysical point of view of corporate control, ineffective) dispersion of stock ownership.
# 10. PP=1.389 | ALP=-0.3289 | The grateful way she looked at morgan made him ashamed of himself.
#
# === Beam search: temperature=5.0, B=5, C=5 ===
#
#  1. PP=1.217 | ALP=-0.1967 | Berman, whose fame has rested in recent years on his skills as a night club monologist, proved himself very much at home in musical comedy.
#  2. PP=1.317 | ALP=-0.2756 | Berman, whose fame has rested in recent years on his skills as a means of resolving fundamental, and certainly no scientific test was made of them.
#  3. PP=1.330 | ALP=-0.2852 | Berman, whose fame has rested in recent years on his skills as a source of policy guidance.
#  4. PP=1.357 | ALP=-0.3055 | Berman, whose fame has rested in recent years on his skills as a means of resolving fundamental, and blue, which miss ada had bought him hung brushed and unworn in the left hand at night, which
#  5. PP=1.368 | ALP=-0.3133 | Berman, whose fame has rested in recent years on his skills as a means of resolving fundamental, and blue, which miss ada had bought him hung brushed and unworn in the next 10 years.
#  6. PP=1.381 | ALP=-0.3228 | Berman, whose fame has rested in recent years on his skills as a means of resolving fundamental, and blue, which miss ada had bought him hung brushed and unworn in the economic development of children, the
#  7. PP=1.383 | ALP=-0.3246 | Just figures out of a permanent peace corps -- a pool of trained american men and women sent overseas by the installation of larger transformers.
#  8. PP=1.391 | ALP=-0.3303 | Berman, whose fame has rested in recent years on his skills as a means of resolving fundamental, and blue, which miss ada had bought him hung brushed and unworn in the closet.
#  9. PP=1.412 | ALP=-0.3448 | Berman, whose fame has rested in recent years on his skills as a means of resolving fundamental, and blue, which julia was holding.
# 10. PP=1.441 | ALP=-0.3654 | Berman, whose fame has rested in recent years on his skills as a means of resolving fundamental, and blue, which miss ada had bought him hung brushed and unworn in the cafeteria, the other the villain

# %% [markdown]
# ### Graded Questions:
#
# #### Part 4A: In the next cell, set `a4a` to the sentence with the smallest perplexity generated by beam search. Use `print_sentence(..., do_print=False)`.

# %%
# Your answer here

# Find the sentence with the smallest perplexity across all beam search results
min_beam_pp = float('inf')
best_beam_sentence_tokens = None

for temp_results in all_beam_results.values():
    for item in temp_results:
        if item['pp'] < min_beam_pp:
            min_beam_pp = item['pp']
            best_beam_sentence_tokens = item['tokens']

a4a = print_sentence(best_beam_sentence_tokens, do_print=False)

# %%
# Graded Answer
# DO NOT change this cell in any way and do not make any other assignments to variable a3a
print(f'a4a = {a4a}')
# Out:
# a4a = The genuinely interesting question, then, becomes: what factors determine the degree of realism or distortion in conventional images of jews??

# %% [markdown]
# #### Part 4B:  Set `a4b` to the perplexity for the sentence you provided in Part 4A.

# %%
# Your answer here

a4b = min_beam_pp

# %%
# Graded Answer
# DO NOT change this cell in any way and do not make any other assignments to variable a4b in this problem

print(f'a4b = {a4b}')
# Out:
# a4b = 1.1937766417144364

# %% [markdown]
# #### Part 4C:  Describe in a few sentences what you observed with the different temperature settings (and try more if you wish!). Which produces the sentences with the best perplexity (you might want to take the average of all 5!).
#
# Your answer here:
# Across beam-search runs (B=5, C=5) the pattern is consistent with prior sampling experiments, but beam search sharpens the effect because it actively preserves high-scoring partials:
#
# Temperature 0.2: Beam search kept very high-probability continuations and produced the best overall perplexities. Outputs are fluent, coherent, and often long (the search favors well-supported phrases). The best finished sentence (PP=1.194) came from T=0.2 (also found at T=1.0 in this run), showing that low temperature plus beam search converges on sequences the model deems most likely.
#
# Temperature 1.0: Results are similar to T=0.2 but slightly more varied; several top candidates tied or were close in PP to the best T=0.2 candidates (PPs in the same low-1.x range). Beam search still prioritized high-probability paths, so perplexities stayed low compared to naive high-temperature sampling.
#
# Temperature 5.0: Beam outputs become more diverse and sometimes oddly phrased; average perplexities rise relative to lower temperatures (worse). The best T=5.0 PPs were noticeably larger than the best PPs at T=0.2/1.0.
#
# Conclusion: beam search combined with low temperature (0.2) produced the best perplexities—i.e., the sentences the model considers most likely. If you average the top finished PPs per temperature (or the top 5), you'll typically find mean_PP(T=0.2) <= mean_PP(T=1.0) < mean_PP(T=5.0). Note that lower perplexity under the model does not always equal better human-judged diversity; beam+low-temp favors safe, high-probability text.

# %% [markdown]
# ## Appendix One: The Brown Corpus
#
# The **Brown Corpus of Standard American English** was compiled at **Brown University** by W. Nelson Francis and Henry Kučera in 1961. It was the **first electronic, balanced corpus of English** ever created and contains about **one million words** drawn from **500 written texts** published in the United States in 1961.
#
# At the time, this was groundbreaking: instead of studying isolated examples, linguists and computer scientists could analyze the **statistical properties of language** across many genres. The Brown Corpus became a **benchmark dataset** in early computational linguistics, psycholinguistics, and later in natural language processing.
#
# ### Genres in the Brown Corpus
#
# The 500 texts were divided evenly across **15 categories**, each representing a different register or style of writing:
#
# * **Press**: reportage, editorials, reviews
# * **General prose**: popular lore, belles lettres, essays
# * **Fiction**: adventure, romance, science fiction, mystery, humor
# * **Learned writing**: academic and scientific publications
# * **Religious writing**: sermons, expository texts
# * **Skills and hobbies**: manuals, do-it-yourself, gardening, sports writing
# * **Government documents**: official reports, public affairs writing
# * **Miscellaneous**: popularized non-fiction, biography
#
# Each category contributes about 2,000 sentences (roughly 80,000 words), ensuring a **balanced sample** of contemporary written English.
#
# ### Examples of Source Texts
#
# While the Brown Corpus does not preserve full books in sequence, the selections were drawn from published works of the time. Examples include:
#
# * **Fiction**: pulp magazines, detective novels, romance stories, humorous fiction.
# * **Press**: articles from major U.S. newspapers and magazines such as *Time* and *Newsweek*.
# * **Religion**: sermons, Bible commentary, religious essays.
# * **Academic**: journal articles in history, sociology, psychology, and linguistics.
# * **Skills and hobbies**: popular magazines like *Popular Mechanics* and *Field & Stream*.
#
# The corpus thus reflects a **snapshot of American English in 1961**: how it was written in popular culture, journalism, science, religion, and government.
#
# ### Why It Matters
#
# * **Historical importance**: the first large corpus, setting the stage for all later corpus linguistics.
# * **Balanced design**: unlike modern web scrapes (e.g., Wikipedia), Brown was carefully curated to capture a **cross-section of genres**.
# * **Still used today**: it remains a teaching resource for exploring **word frequencies, n-grams, Zipf’s law, and stylistic differences across genres**.
#
# ### Categories in the Brown Corpus
#
# The Brown Corpus is divided into 15 genres, each with about 80,000 words (for a total of ~1 million). This balance makes it useful for studying stylistic and lexical variation across English.
#
# | Code | Category              | Description / Examples                                  |
# |------|-----------------------|---------------------------------------------------------|
# | A    | Press: Reportage      | Straight news reporting; newspaper and magazine articles |
# | B    | Press: Editorial      | Opinion pieces and editorials from newspapers/magazines |
# | C    | Press: Reviews        | Reviews of books, plays, music, films                   |
# | D    | Religion              | Sermons, religious commentary, Bible studies            |
# | E    | Skills & Hobbies      | How-to manuals, sports, leisure, do-it-yourself         |
# | F    | Popular Lore          | Popular science, cultural essays, lore                  |
# | G    | Belles Lettres        | Literary essays, non-fiction with artistic style        |
# | H    | Miscellaneous         | Biographies, memoirs, other non-fiction                 |
# | J    | Learned               | Academic and scientific writing                         |
# | K    | General Fiction       | Short stories and novels, general fiction               |
# | L    | Mystery & Detective   | Detective and crime fiction                             |
# | M    | Science Fiction       | Science fiction stories and novels                      |
# | N    | Adventure & Western   | Adventure stories, Westerns                             |
# | P    | Romance               | Romantic fiction                                        |
# | R    | Humor                 | Humorous fiction and essays                             |
#
# Together these categories provide a **snapshot of American English in 1961**, from journalism and government reports to pulp fiction and academic writing.

# %%
for p in [1,1/2,1/3,1/4, 0.01, 1e-10]:
          print(math.log(p))
# Out:
# 0.0
# -0.6931471805599453
# -1.0986122886681098
# -1.3862943611198906
# -4.605170185988091
# -23.025850929940457

# %% [markdown]
# ## Appendix Two: Using Log-Probabilities in N-Gram Models
#
# When working with **n-gram language models**, we calculate the probability of a sentence by multiplying the conditional probabilities of each word:
#
# $$
# P(w_1, w_2, \dots, w_n) = \prod_{i=1}^n P(w_i \mid \text{context})
# $$
#
# ### Do we really need logs for the Brown Corpus?
#
# In the Brown Corpus, the **longest sentence has 182 tokens**. That’s not very long compared to modern corpora, so you might think multiplying probabilities directly is fine. For example:
#
# * If the average conditional probability were around $0.1$, the longest Brown sentence has probability about
#   $$(0.1)^{182} = 10^{-182},$$
#   which is still representable in double precision (smallest positive $\approx 10^{-324}$).
#
# * But if the average probability were closer to $0.01$, then
#   $$(0.01)^{182} = 10^{-364},$$
#   which would **underflow to 0**.
#
# So in some cases you’d be safe, in others not.
#
# ### Some Examples of Log Probabilities
#
# Since probabilities are always in the range $[0,1.0]$, log probabilities are in the range $[-\infty,0.0]$. Here are
# some examples of log probabilities (we'll use natural logs, but the base really doesn't matter):
#
#     Probability         Log Probability
#       1.0                 0.0
#       1/2                -0.6931471805599453
#       1/3                -1.0986122886681098
#       1/4                -1.3862943611198906
#       0.01               -4.605170185988091
#       1e-10              -23.025850929940457
#       1e-1000            -2302.5850929940457
#
# (To put this in somewhat real terms, suppose you and a friend could both randomly choose an **atom** somewhere in the observable
# universe: the probability that you both choose the same atom is approximately 1e-80.)
#
# ### Why we use log-probabilities anyway
#
# Even if underflow is not common in Brown sentences, there are three strong reasons to switch to log-space:
#
# 1. **Smoothing produces tiny probabilities.** With add-one or Kneser–Ney smoothing, many n-grams have very small values, making underflow more likely.
# 2. **Corpus-level calculations.** Perplexity is often computed over *all tokens* in the corpus. With Brown’s ~1M tokens, multiplying raw probabilities is completely impossible.
# 3. **Consistency with NLP practice.** Modern language models (n-gram and neural alike) always work in log-space. Teaching it here ensures the method scales to larger datasets like Shakespeare, WikiText, or web-scale corpora.
#
# ### The log-space trick
#
# Recall how computing in log-space works:
#
# - Convert your numbers to logs
# - Instead of multiplying, add
# - Instead of exponentiation, multiply
# - If you need to sort, or compare using $\lt$ or $\le$, just do it in log-space (since it is monotonic, i.e., preserves order)
# - Convert back to normal if you want to print it out in human-readable form as a metric or use it with code that expects normal probabilities (e.g., softmax, or sampling).
#
# Thus, instead of multiplying probabilities, we sum log probabilities:
#
# $$
# \log P(w_1, w_2, \dots, w_n) = \sum_{i=1}^n \log P(w_i \mid \text{context})
# $$
#
# This prevents underflow, keeps values in a manageable numeric range, and makes computation easier.
#
# * **Ranking:** For decoding or beam search, you can use log-probabilities directly, since $\log$ is monotonic. No conversion back is needed.
# * **Perplexity:**
#
# $$
# \text{PP} = \exp\left(-\tfrac{1}{n} \sum_{i=1}^n \log P(w_i \mid \text{context})\right)
# $$
#
# Here the exponential is applied only at the end.
#
# * **Sampling:** To draw the next word, convert log-probabilities back with `exp()` to normalize.
#
# ---
#
# ✅ **TL;DR Summary:** In the Brown Corpus, you *might* get away with raw probabilities for single sentences, but log-space is essential once you apply smoothing, compute perplexity over the whole corpus, or move to larger datasets. It’s also the standard method in NLP, so it’s best to learn it now.
